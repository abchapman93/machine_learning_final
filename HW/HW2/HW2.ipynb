# %%
import os
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
DATADIR = os.path.join(os.getcwd(),'Homework 2 Resources')
os.path.exists(DATADIR)
from numpy import random as rnd

# %%
fFeatures = os.path.join(DATADIR, 'X.txt')
fLabels = os.path.join(DATADIR, 'y.txt')

with open(fFeatures,'r') as f0:
    X = np.array([float(x.strip()) for x in f0.readlines()])
with open(fLabels,'r') as f1:
    y = np.array([float(x.strip()) for x in f1.readlines()])
X_new = np.c_[np.ones((100,1)),X]
np.shape(X_new)

# %%
plt.scatter(X,y)

# %%
#normal equation
import numpy.linalg as LA
theta_best = LA.inv(X_new.T.dot(X_new)).dot(X_new.T).dot(y)
theta_best
# Out:
# array([ 13.98918882,   6.82242882])

# %%
y_normal = [theta_best[0] + theta_best[1]*x for x in X]
y_predict=X_new.dot(theta_best)

# %%
plt.scatter(X,y_predict)
plt.plot(X, y_normal,"r_",linewidth=2)
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
#plt.axis([0, 2, 0, 15])

plt.show()
# Out:
# /Users/alec/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
learning_rates = [0.0001, 0.01, 0.5]

# %%
def gradient_descent(X, y, eta, n_iterations, theta=rnd.randn(2,1)):
    for iteration in range(n_iterations):
        gradients = 2/len(X) * X.T.dot(X.dot(theta)-y)
        theta = theta - eta*gradients
    print(np.shape(X))
    print(np.shape(theta))
    return theta

# %%
thetas = gradient_descent(X_new, y, learning_rates[2],2000)
# Out:
# (100, 2)
# (2, 100)

# %%
y_predict = X_new.dot(thetas)

# %%
#Report model parameters for the first 5 descent iterations and final iteration
#Graph the state of the hypothesis every 200th iteration

def plot_grad_descent(X, y,theta, eta=None, n_iterations=2001 ,theta_path=None):
    
    #plt.plot(X, y, "b.")
    X_b = np.c_[np.ones((100,1)), X]
    m = len(X_b)
    X_new = np.array([[0],[2]]) #I don't know what this does
    X_new_b = np.c_[np.ones((2, 1)), X_new]
    gradients = (2/m) * X_b.T.dot(X_b.dot(theta)-y)
    for iteration in range(n_iterations):
        if iteration > 5:
            y_predict = X_new_b.dot(theta)
            style = "b-" if iteration > 0 else "r--"
            #plt.plot(X_new, y_predict,style)
        
        print(len(gradients))
        return gradients
        print("len of gradients:",len(gradients))
        print('eta:', eta)
        print('theta before:',np.size(theta))
        print(np.size(theta))
        theta = theta - eta * gradients
        print('after:')
        print(np.size(theta))
    return
    if theta_path is not None:
        theta_path.append(theta)
    y_predict = X_new_b.dot(theta)
    
    plt.plot(X,y,"b.")
    plt.plot(X_new, y_predict, "r-", linewidth=2, label="Predictions")
    plt.xlabel("$x_1$",fontsize=18)
    plt.ylabel("$y$", rotation=0, fontsize=18)
    plt.legend(loc="upper left", fontsize=14)
    
    return theta
    for iteration in range(n_iterations):    
        plt.plot(X,y,"b.")
        
        
        
        #if iteration <= 5.0:
            #first_five_thetas.append(theta)
        if iteration == 2000:
            print(np.shape(theta))
            print(iteration)
            plt.scatter(X,thetas.T)
            plt.show()
            return
    #print('First five:',first_five_thetas)
    #print('Every 200th:', iterations_200)
    return

# %%
theta = rnd.randn(2,1)
plot_grad_descent(X, y, theta, eta=0.1,n_iterations=5,theta_path=[])
# Out:
# 2
# array([[-52.80782531, -55.13486531, -52.15770531, -43.65604531,
